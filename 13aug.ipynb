# %% [markdown]
# today's chapters
# data type   :
# 1  int
# 2  float
# 3  bool
# 4 complex
# 5 string

# %% [markdown]
# 1 int
# Stores whole numbers without decimal points.
# 2 float
# Stores numbers with decimal points.
# 3 bool
# Stores logical values: True or False.
# 4 complex
# Stores complex numbers with real and imaginary parts.
# 5 string
# Stores a sequence of characters/text.

# %% [markdown]
# 1 string
# Stores text and characters.
# Strings are immutable (cannot be changed directly).
# Supports indexing and slicing.
# Can contain letters, numbers, spaces, and special characters.
#
# syntax :
# Strings are written inside single (' '), double (" "), or (''' '''' )("""   """"  ) triple quotes.

# %%
# code 
s1= ' pune ' 
s2= " indian " 
s3 = """ menu 
            1 addtion 
            2 sub 
            3 mul  """
print(s1)
print(s2)
print(s3)
print( type(s1), type ( s2 ), type ( s3 ))
# Out:
#  pune
#  indian
#  menu
#             1 addtion
#             2 sub
#             3 mul
# <class 'str'> <class 'str'> <class 'str'>

# %% [markdown]
# Slicing is used to extract a part of a sequence, such as a string, list, or tuple.
# syntax:
#
# sequence[start:stop:step]
# var[start_index : end_index    ]
#
#
#  blankspace also the add .
#  the index [ 0 to last ] in the following string .
#  left to right start from -1 to end of the string .

# %%
# code 
s="instagram"
print( len(s))
print(s[-5])
print(s[6])


print( s [3], s[4], s[5])
print(s[3]+s[4]+s[5])
# Out:
# 9
# a
# r
# t a g
# tag

# %% [markdown]
# any five opration on string using the slice opeartion ..
# 1 negative index
# 2 combination of negative as well as positive

# %%
s= " paragshobhilaluikey "  # last having the blankspace so it having index 
print(len(s))
print(s[-7], s[-8], s[-9])
print(s[-7]+ s[-8]+ s[-9])
print(s[-18]+ s[-17]+ s[-16]+s[-8])
print(s[]+s[]+s[]+s[])
# Out:
# 21
# l a l
# lal
# raga
